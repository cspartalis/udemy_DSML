# %% [markdown]
# # Section 8 - Python for Data Visualization -Matplotlib
# ___
# ### Very useful --> [Matplotlib_Gallery](https://matplotlib.org/gallery/index.html)
# ___

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# ## Functional method

# %%
x = np.linspace(0,5,10)
y = x ** 2

plt.plot(x,y)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Example')
plt.show()    #not needed in jupyter

# %% [markdown]
# #### Subplots
# * **plt.subplot( scaling_of_x_axis, scaling_of_y_axis, #plot)**

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')
plt.show()

# %% [markdown]
# ## Object Oriented method [Recommended]
# * Create figure objects and then just call methods off of these
# * .add_axes([left, bottom, width, height)] --> _They are all percentages_

# %%
fig = plt.figure()    #create blank canvas
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])


axes.set_xlabel('X axis')
axes.set_ylabel('Y axis')
axes.set_title('OO Example')

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])    #distance from margins
axes2 = fig.add_axes([0.2,0.5,0.4,0.4])    #distamce from margins

axes1.plot(x,y)
axes2.plot(y,x)
plt.show()
# Out:
# /home/kaml/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %% [markdown]
# #### Subplots
# * plt.subplots() differs from plt.figure() on that the fig.add_axes() is automated.
# * plt.subplots( #rows, #cols )
# * _axes_(variable) is an array of axes so i can iterate it.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)    #tuple unpacking
plt.tight_layout()                            #fix overlaps

axes[0][0].plot(x,y,'r')
axes[0][1].plot(x,y,'go')
axes[1][0].plot(y,x,'m*')
axes[1][1].plot(y,x,'b')
plt.show()

# %% [markdown]
# ## Figure Size and DPI
# * ( figsize = ( width_in_inches, height_in_inches ), dpi = dots_per_inch )

# %%
fig = plt.figure(figsize=(3,2), dpi=100)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,'r')

fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(3,2), dpi=100)
ax[0].plot(x,y,'mo')
ax[1].plot(y,x,'mx')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Save Figures

# %%
fig.savefig('my_picture.png', dpi=200)

# %% [markdown]
# ## Legend
# * ax.legend(loc=1)   # upper right corner
# * ax.legend(loc=2)   # upper left corner
# * ax.legend(loc=3)   # lower left corner
# * ax.legend(loc=4)   # lower right corner
# * else... ax.legend(loc=(0.1, 0.1)) # manually

# %%
fig = plt.figure(figsize=(4,3), dpi=100)
ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2, label='X Squared')
ax.plot(x,x**3, label='X Cubed')
ax.legend(loc=0)  #best location loc=0

plt.show()

# %% [markdown]
# ## Plot Appearance

# %%
fig, ax = plt.subplots()

ax.plot(x, x+1, color="blue", alpha=0.5) # half-transparant
ax.plot(x, x+2, color="#8B008B")        # RGB hex code
ax.plot(x, x+3, color="#FF8C00")        # RGB hex code 

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [markdown]
# ## Plot range
# ___
# We can configure the ranges of the axes using the `set_ylim` and `set_xlim` methods in the axis object, or `axis('tight')` for automatically getting "tightly fitted" axes ranges:

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %% [markdown]
# ## Special Plot Types

# %%
#SCATTER
plt.scatter(x,y)
plt.show()

# %%
#HISTOGRAMM
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([15., 15.,  7.,  6., 11., 11.,  7., 10.,  8., 10.]),
#  array([ 10. , 106.3, 202.6, 298.9, 395.2, 491.5, 587.8, 684.1, 780.4,
#         876.7, 973. ]),
#  <a list of 10 Patch objects>)

# %%
#BOXPLOT
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);
